# %%
import pandas as pd
import sqlite3

# %%
orders = pd.read_csv("C:/Users/saies/OneDrive/Desktop/IRL HACKATHON/DATA/orders.csv")

# %%
orders
# Out:
#       order_id  user_id  restaurant_id  order_date  total_amount  \
# 0            1     2508            450  18-02-2023        842.97
# 1            2     2693            309  18-01-2023        546.68
# 2            3     2084            107  15-07-2023        163.93
# 3            4      319            224  04-10-2023       1155.97
# 4            5     1064            293  25-12-2023       1321.91
# ...        ...      ...            ...         ...           ...
# 9995      9996     2528            249  21-05-2023       1211.96
# 9996      9997     2867            267  06-08-2023       1188.05
# 9997      9998      522            420  11-11-2023        979.44
# 9998      9999      319            492  08-09-2023       1105.93
# 9999     10000      457            439  21-10-2023        879.58
#
#                      restaurant_name
# 0                  New Foods Chinese
# 1     Ruchi Curry House Multicuisine
# 2              Spice Kitchen Punjabi
# ...

# %%
orders.head()
# Out:
#    order_id  user_id  restaurant_id  order_date  total_amount  \
# 0         1     2508            450  18-02-2023        842.97
# 1         2     2693            309  18-01-2023        546.68
# 2         3     2084            107  15-07-2023        163.93
# 3         4      319            224  04-10-2023       1155.97
# 4         5     1064            293  25-12-2023       1321.91
#
#                   restaurant_name
# 0               New Foods Chinese
# 1  Ruchi Curry House Multicuisine
# 2           Spice Kitchen Punjabi
# 3          Darbar Kitchen Non-Veg
# 4       Royal Eatery South Indian

# %%
orders.tail()
# Out:
#       order_id  user_id  restaurant_id  order_date  total_amount  \
# 9995      9996     2528            249  21-05-2023       1211.96
# 9996      9997     2867            267  06-08-2023       1188.05
# 9997      9998      522            420  11-11-2023        979.44
# 9998      9999      319            492  08-09-2023       1105.93
# 9999     10000      457            439  21-10-2023        879.58
#
#                      restaurant_name
# 9995      Royal Kitchen North Indian
# 9996             Darbar Cafe Punjabi
# 9997           Ruchi Tiffins Chinese
# 9998    Swagath Kitchen North Indian
# 9999  Classic Cafe Family Restaurant

# %%
users = pd.read_json("C:/Users/saies/OneDrive/Desktop/IRL HACKATHON/DATA/users.json")

# %%
users.head()
# Out:
#    user_id    name       city membership
# 0        1  User_1    Chennai    Regular
# 1        2  User_2       Pune       Gold
# 2        3  User_3  Bangalore       Gold
# 3        4  User_4  Bangalore    Regular
# 4        5  User_5       Pune       Gold

# %%
users.tail()
# Out:
#       user_id       name       city membership
# 2995     2996  User_2996  Hyderabad       Gold
# 2996     2997  User_2997  Hyderabad    Regular
# 2997     2998  User_2998  Bangalore    Regular
# 2998     2999  User_2999       Pune    Regular
# 2999     3000  User_3000  Hyderabad       Gold

# %%
conn = sqlite3.connect("restaurants.db")

# %%
conn.execute("DROP TABLE IF EXISTS restaurants;")
with open("C:/Users/saies/OneDrive/Desktop/IRL HACKATHON/DATA/restaurants.sql", "r") as file:
    sql_script = file.read()
conn.executescript(sql_script)

# %%
restaurants = pd.read_sql("SELECT * FROM restaurants", conn)

# %%
restaurants
# Out:
#      restaurant_id restaurant_name  cuisine  rating
# 0                1    Restaurant_1  Chinese     4.8
# 1                2    Restaurant_2   Indian     4.1
# 2                3    Restaurant_3  Mexican     4.3
# 3                4    Restaurant_4  Chinese     4.1
# 4                5    Restaurant_5  Chinese     4.8
# ..             ...             ...      ...     ...
# 495            496  Restaurant_496   Indian     3.1
# 496            497  Restaurant_497  Mexican     4.4
# 497            498  Restaurant_498  Chinese     3.9
# 498            499  Restaurant_499  Mexican     4.9
# 499            500  Restaurant_500  Chinese     3.2
#
# [500 rows x 4 columns]

# %%
restaurants.head()
# Out:
#    restaurant_id restaurant_name  cuisine  rating
# 0              1    Restaurant_1  Chinese     4.8
# 1              2    Restaurant_2   Indian     4.1
# 2              3    Restaurant_3  Mexican     4.3
# 3              4    Restaurant_4  Chinese     4.1
# 4              5    Restaurant_5  Chinese     4.8

# %%
restaurants.tail()
# Out:
#      restaurant_id restaurant_name  cuisine  rating
# 495            496  Restaurant_496   Indian     3.1
# 496            497  Restaurant_497  Mexican     4.4
# 497            498  Restaurant_498  Chinese     3.9
# 498            499  Restaurant_499  Mexican     4.9
# 499            500  Restaurant_500  Chinese     3.2

# %%
restaurants.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   restaurant_id    500 non-null    int64
#  1   restaurant_name  500 non-null    object
#  2   cuisine          500 non-null    object
#  3   rating           500 non-null    float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 15.8+ KB

# %%
orders_users = pd.merge(
    orders,
    users,
    on="user_id",
    how="left"
)

# %%
orders_users
# Out:
#       order_id  user_id  restaurant_id  order_date  total_amount  \
# 0            1     2508            450  18-02-2023        842.97
# 1            2     2693            309  18-01-2023        546.68
# 2            3     2084            107  15-07-2023        163.93
# 3            4      319            224  04-10-2023       1155.97
# 4            5     1064            293  25-12-2023       1321.91
# ...        ...      ...            ...         ...           ...
# 9995      9996     2528            249  21-05-2023       1211.96
# 9996      9997     2867            267  06-08-2023       1188.05
# 9997      9998      522            420  11-11-2023        979.44
# 9998      9999      319            492  08-09-2023       1105.93
# 9999     10000      457            439  21-10-2023        879.58
#
#                      restaurant_name       name       city membership
# 0                  New Foods Chinese  User_2508  Hyderabad    Regular
# ...

# %%
orders_users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   order_id         10000 non-null  int64
#  1   user_id          10000 non-null  int64
#  2   restaurant_id    10000 non-null  int64
#  3   order_date       10000 non-null  object
#  4   total_amount     10000 non-null  float64
#  5   restaurant_name  10000 non-null  object
#  6   name             10000 non-null  object
#  7   city             10000 non-null  object
#  8   membership       10000 non-null  object
# dtypes: float64(1), int64(3), object(5)
# memory usage: 703.3+ KB

# %%
final = pd.merge(
    orders_users,
    restaurants,
    on="restaurant_id",
    how="left"
)

# %%
final
# Out:
#       order_id  user_id  restaurant_id  order_date  total_amount  \
# 0            1     2508            450  18-02-2023        842.97
# 1            2     2693            309  18-01-2023        546.68
# 2            3     2084            107  15-07-2023        163.93
# 3            4      319            224  04-10-2023       1155.97
# 4            5     1064            293  25-12-2023       1321.91
# ...        ...      ...            ...         ...           ...
# 9995      9996     2528            249  21-05-2023       1211.96
# 9996      9997     2867            267  06-08-2023       1188.05
# 9997      9998      522            420  11-11-2023        979.44
# 9998      9999      319            492  08-09-2023       1105.93
# 9999     10000      457            439  21-10-2023        879.58
#
#                    restaurant_name_x       name       city membership  \
# 0                  New Foods Chinese  User_2508  Hyderabad    Regular
# ...

# %%
final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   order_id           10000 non-null  int64
#  1   user_id            10000 non-null  int64
#  2   restaurant_id      10000 non-null  int64
#  3   order_date         10000 non-null  object
#  4   total_amount       10000 non-null  float64
#  5   restaurant_name_x  10000 non-null  object
#  6   name               10000 non-null  object
#  7   city               10000 non-null  object
#  8   membership         10000 non-null  object
#  9   restaurant_name_y  10000 non-null  object
#  10  cuisine            10000 non-null  object
#  11  rating             10000 non-null  float64
# dtypes: float64(2), int64(3), object(7)
# memory usage: 937.6+ KB

# %%
final.to_csv("C:/Users/saies/OneDrive/Desktop/IRL HACKATHON/DATA/total_food_dataset.csv", index=False)

# %%
rest = pd.read_csv("C:/Users/saies/OneDrive/Desktop/IRL HACKATHON/DATA/total_food_dataset.csv")

# %%
rest
# Out:
#       order_id  user_id  restaurant_id  order_date  total_amount  \
# 0            1     2508            450  18-02-2023        842.97
# 1            2     2693            309  18-01-2023        546.68
# 2            3     2084            107  15-07-2023        163.93
# 3            4      319            224  04-10-2023       1155.97
# 4            5     1064            293  25-12-2023       1321.91
# ...        ...      ...            ...         ...           ...
# 9995      9996     2528            249  21-05-2023       1211.96
# 9996      9997     2867            267  06-08-2023       1188.05
# 9997      9998      522            420  11-11-2023        979.44
# 9998      9999      319            492  08-09-2023       1105.93
# 9999     10000      457            439  21-10-2023        879.58
#
#                    restaurant_name_x       name       city membership  \
# 0                  New Foods Chinese  User_2508  Hyderabad    Regular
# ...

# %%
rest.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   order_id           10000 non-null  int64
#  1   user_id            10000 non-null  int64
#  2   restaurant_id      10000 non-null  int64
#  3   order_date         10000 non-null  object
#  4   total_amount       10000 non-null  float64
#  5   restaurant_name_x  10000 non-null  object
#  6   name               10000 non-null  object
#  7   city               10000 non-null  object
#  8   membership         10000 non-null  object
#  9   restaurant_name_y  10000 non-null  object
#  10  cuisine            10000 non-null  object
#  11  rating             10000 non-null  float64
# dtypes: float64(2), int64(3), object(7)
# memory usage: 937.6+ KB

# %%
final.shape
# Out:
# (10000, 12)

# %%
final.isnull().sum()
# Out:
# order_id             0
# user_id              0
# restaurant_id        0
# order_date           0
# total_amount         0
# restaurant_name_x    0
# name                 0
# city                 0
# membership           0
# restaurant_name_y    0
# cuisine              0
# rating               0
# dtype: int64

# %%
final.columns
# Out:
# Index(['order_id', 'user_id', 'restaurant_id', 'order_date', 'total_amount',
#        'restaurant_name_x', 'name', 'city', 'membership', 'restaurant_name_y',
#        'cuisine', 'rating'],
#       dtype='object')

# %%
final.groupby("city")["total_amount"].sum()
# Out:
# city
# Bangalore    2206946.58
# Chennai      1990513.03
# Hyderabad    1889366.58
# Pune         1924797.93
# Name: total_amount, dtype: float64

# %%
final["membership"].value_counts()
# Out:
# membership
# Regular    5013
# Gold       4987
# Name: count, dtype: int64

# %%
final.groupby("cuisine")["total_amount"].mean()
# Out:
# cuisine
# Chinese    798.389020
# Indian     798.466011
# Italian    799.448578
# Mexican    808.021344
# Name: total_amount, dtype: float64

# %%
final[final["membership"] == "Gold"] \
    .groupby("city")["total_amount"] \
    .sum() \
    .sort_values(ascending=False)
# Out:
# city
# Chennai      1080909.79
# Pune         1003012.32
# Bangalore     994702.59
# Hyderabad     896740.19
# Name: total_amount, dtype: float64

# %%
final.groupby("cuisine")["total_amount"] \
    .mean() \
    .sort_values(ascending=False)
# Out:
# cuisine
# Mexican    808.021344
# Italian    799.448578
# Indian     798.466011
# Chinese    798.389020
# Name: total_amount, dtype: float64

# %%
user_spend = final.groupby("user_id")["total_amount"].sum()
(user_spend > 1000).sum()
# Out:
# np.int64(2544)

# %%
final["rating_range"] = pd.cut(
    final["rating"],
    bins=[3.0, 3.5, 4.0, 4.5, 5.0],
    labels=["3.0–3.5", "3.6–4.0", "4.1–4.5", "4.6–5.0"]
)

final.groupby("rating_range", observed=True)["total_amount"] \
     .sum() \
     .sort_values(ascending=False)
# Out:
# rating_range
# 4.6–5.0    2197030.75
# 4.1–4.5    1960326.26
# 3.0–3.5    1881754.57
# 3.6–4.0    1717494.41
# Name: total_amount, dtype: float64

# %%
final[final["membership"] == "Gold"] \
    .groupby("city")["total_amount"] \
    .mean() \
    .sort_values(ascending=False)
# Out:
# city
# Chennai      808.459080
# Hyderabad    806.421034
# Bangalore    793.223756
# Pune         781.162243
# Name: total_amount, dtype: float64

# %%
restaurant_count = final.groupby("cuisine")["restaurant_id"].nunique()
revenue = final.groupby("cuisine")["total_amount"].sum()
pd.concat([restaurant_count, revenue], axis=1) \
  .rename(columns={"restaurant_id": "restaurant_count"}) \
  .sort_values("restaurant_count")
# Out:
#          restaurant_count  total_amount
# cuisine
# Chinese               120    1930504.65
# Indian                126    1971412.58
# Italian               126    2024203.80
# Mexican               128    2085503.09

# %%
gold_orders = final[final["membership"] == "Gold"].shape[0]
total_orders = final.shape[0]
round((gold_orders / total_orders) * 100)
# Out:
# 50

# %%
final.groupby(["membership", "cuisine"])["total_amount"] \
    .sum() \
    .sort_values(ascending=False)
# Out:
# membership  cuisine
# Regular     Mexican    1072943.30
#             Italian    1018424.75
# Gold        Mexican    1012559.79
#             Italian    1005779.05
# Regular     Indian      992100.27
# Gold        Indian      979312.31
#             Chinese     977713.74
# Regular     Chinese     952790.91
# Name: total_amount, dtype: float64

# %%
final["order_date"] = pd.to_datetime(final["order_date"], dayfirst=True)
final_df["quarter"] = final_df["order_date"].dt.to_period("Q")

final_df.groupby("quarter")["total_amount"] \
    .sum() \
    .sort_values(ascending=False)
# Out:
# quarter
# 2023Q3    2037385.10
# 2023Q4    2018263.66
# 2023Q1    1993425.14
# 2023Q2    1945348.72
# 2024Q1      17201.50
# Freq: Q-DEC, Name: total_amount, dtype: float64

# %%
final[final["membership"] == "Gold"].shape[0]
# Out:
# 4987

# %%
round(
    final[final["city"] == "Hyderabad"]["total_amount"].sum()
)
# Out:
# 1889367

# %%
final["user_id"].nunique()
# Out:
# 2883

# %%
round(
    final[final["membership"] == "Gold"]["total_amount"].mean(),
    2
)
# Out:
# np.float64(797.15)

# %%
final[final["rating"] >= 4.5].shape[0]
# Out:
# 3374

# %%
top_city = (
    final[final["membership"] == "Gold"]
    .groupby("city")["total_amount"]
    .sum()
    .idxmax()
)

final[
    (final["membership"] == "Gold") &
    (final["city"] == top_city)
].shape[0]
# Out:
# 1337
